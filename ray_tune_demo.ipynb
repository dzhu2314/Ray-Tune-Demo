# %% [markdown]
# # 17445 Fall 2024 Homework 3: Tools for Production ML Systems
#
# ## Ray Tune - Hyperparameter Optimization and Experimentation
#
# ## Demo by: Derek Zhu
#
# The following demo was designed and tested using Google Colab.

# %%
# Install Surprise and Ray Tune
# !pip install scikit-surprise
# !pip install "ray[tune]"

# %%
# Import libraries
import pandas as pd
import json
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import cross_validate, train_test_split
from ray import train, tune
from ray.train import RunConfig
from ray.tune.schedulers import ASHAScheduler

# %%
# Load and pre-process data
users_df = pd.read_csv('users.csv').dropna()
user_watched_df = pd.read_csv('user_watched.csv').dropna()
movies_df = pd.read_csv('movies.csv').dropna()

merged_df = user_watched_df.merge(users_df, on = 'user_id').merge(movies_df, left_on = 'movie_id', right_on = 'id')
merged_df = merged_df[merged_df['rating'] != -1]

# Prepare data for SVD model
reader = Reader(rating_scale = (1, 5))
data = Dataset.load_from_df(merged_df[['user_id', 'id', 'rating']], reader)
train_data, test_data = train_test_split(data, test_size = 0.2, random_state = 2314)

# %%
# Train the model based on hyperparameters in config and output metrics to optimize on
def objective(config):
  svd = SVD(n_factors = config["n_factors"], n_epochs = config["n_epochs"],
            lr_all = config["lr_all"], reg_all = config["reg_all"])
  svd.fit(train_data)

  train_predictions = svd.test(train_data.all_ratings())
  train_rmse = accuracy.rmse(train_predictions)
  predictions = svd.test(test_data)
  rmse = accuracy.rmse(predictions)
  rmse_difference = train_rmse - rmse

  return {"train_rmse": train_rmse, "rmse": rmse, "rmse_difference": rmse_difference}

# Define the search space for hyperparameters of SVD model
search_space = {
    "n_factors": tune.grid_search([50, 100, 200]),     # default 100
    "n_epochs": tune.grid_search([10, 20, 40]),        # default 20
    "lr_all": tune.grid_search([0.0025, 0.005, 0.01]), # default 0.005
    "reg_all": tune.grid_search([0.01, 0.02, 0.04])    # default 0.02
}

# Initialize Tuner
# TuneConfig: Use ASHA scheduling to abandon trials underperforming on rmse
# RunConfig: Set file path to store results
tuner = tune.Tuner(objective, param_space = search_space,
                   tune_config = tune.TuneConfig(scheduler = ASHAScheduler(), metric = "rmse", mode = "min"),
                   run_config = RunConfig(storage_path = "/content/results", name = "demo_experiment"))

# Conduct trials defined by the search_space and print the best model based on minimum rmse
results = tuner.fit()
print("Lowest RMSE Model:", results.get_best_result(metric = "rmse", mode = "min").config)
# Out:
# 2024-11-03 21:48:39,728	INFO worker.py:1816 -- Started a local Ray instance.
# 2024-11-03 21:48:41,414	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +----------------------------------------------------------+
# | Configuration for experiment     demo_experiment         |
# +----------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator   |
# | Scheduler                        AsyncHyperBandScheduler |
# | Number of trials                 81                      |
# +----------------------------------------------------------+
#
# View detailed results here: /content/results/demo_experiment
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2024-11-03_21-48-36_244092_570/artifacts/2024-11-03_21-48-41/demo_experiment/driver_artifacts`
#
# Trial status: 81 PENDING
# Current time: 2024-11-03 21:48:53. Total running time: 7s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------+
# | Trial name              status       n_factors     n_epochs     lr_all     reg_all |
# +------------------------------------------------------------------------------------+
# | objective_64145_00000   PENDING             50           10     0.0025        0.01 |
# | objective_64145_00001   PENDING             50           10     0.005         0.01 |
# | objective_64145_00002   PENDING             50           10     0.01          0.01 |
# | objective_64145_00003   PENDING             50           20     0.0025        0.01 |
# | objective_64145_00004   PENDING             50           20     0.005         0.01 |
# +------------------------------------------------------------------------------------+
# 76 more PENDING
#
# Trial objective_64145_00000 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00000 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   10 |
# | n_factors                                  50 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00001 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00001 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  10 |
# | n_factors                                 50 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00000 completed after 1 iterations at 2024-11-03 21:48:56. Total running time: 10s
# +------------------------------------------------+
# | Trial objective_64145_00000 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.24603 |
# | time_total_s                           0.24603 |
# | training_iteration                           1 |
# | rmse                                   0.85593 |
# | rmse_difference                        0.04458 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
# (objective pid=1718) RMSE: 0.9005
# (objective pid=1718) RMSE: 0.8559
#
# Trial objective_64145_00001 completed after 1 iterations at 2024-11-03 21:48:56. Total running time: 10s
# +------------------------------------------------+
# | Trial objective_64145_00001 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.24384 |
# | time_total_s                           0.24384 |
# | training_iteration                           1 |
# | rmse                                   0.84773 |
# | rmse_difference                        0.05277 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
#
# Trial objective_64145_00003 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00003 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   20 |
# | n_factors                                  50 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00002 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00002 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 10 |
# | n_factors                                50 |
# | reg_all                                0.01 |
# +---------------------------------------------+
# (objective pid=1880) RMSE: 0.8458 [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
#
# Trial objective_64145_00003 completed after 1 iterations at 2024-11-03 21:49:03. Total running time: 17s
# +------------------------------------------------+
# | Trial objective_64145_00003 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.56142 |
# | time_total_s                           0.56142 |
# | training_iteration                           1 |
# | rmse                                   0.84584 |
# | rmse_difference                        0.05466 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
#
# Trial objective_64145_00002 completed after 1 iterations at 2024-11-03 21:49:03. Total running time: 17s
# +------------------------------------------------+
# | Trial objective_64145_00002 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.36288 |
# | time_total_s                           0.36288 |
# | training_iteration                           1 |
# | rmse                                   0.84311 |
# | rmse_difference                        0.05763 |
# | train_rmse                             0.90074 |
# +------------------------------------------------+
#
# Trial objective_64145_00004 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00004 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  20 |
# | n_factors                                 50 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00005 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00005 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 20 |
# | n_factors                                50 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00004 completed after 1 iterations at 2024-11-03 21:49:09. Total running time: 23s
# +------------------------------------------------+
# | Trial objective_64145_00004 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.30948 |
# | time_total_s                           0.30948 |
# | training_iteration                           1 |
# | rmse                                   0.84329 |
# | rmse_difference                        0.05744 |
# | train_rmse                             0.90073 |
# +------------------------------------------------+
# (objective pid=2046) RMSE: 0.8433 [repeated 4x across cluster]
#
# Trial objective_64145_00005 completed after 1 iterations at 2024-11-03 21:49:10. Total running time: 24s
# +------------------------------------------------+
# | Trial objective_64145_00005 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.29589 |
# | time_total_s                           0.29589 |
# | training_iteration                           1 |
# | rmse                                   0.83818 |
# | rmse_difference                        0.06341 |
# | train_rmse                             0.90159 |
# +------------------------------------------------+
#
# Trial objective_64145_00006 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00006 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   40 |
# | n_factors                                  50 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00007 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00007 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  40 |
# | n_factors                                 50 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
# (objective pid=2198) RMSE: 0.8408 [repeated 4x across cluster]
#
# Trial objective_64145_00006 completed after 1 iterations at 2024-11-03 21:49:15. Total running time: 29s
# +------------------------------------------------+
# | Trial objective_64145_00006 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.50759 |
# | time_total_s                           0.50759 |
# | training_iteration                           1 |
# | rmse                                   0.84076 |
# | rmse_difference                        0.05999 |
# | train_rmse                             0.90075 |
# +------------------------------------------------+
#
# Trial objective_64145_00007 completed after 1 iterations at 2024-11-03 21:49:15. Total running time: 29s
# +------------------------------------------------+
# | Trial objective_64145_00007 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                        0.5094 |
# | time_total_s                            0.5094 |
# | training_iteration                           1 |
# | rmse                                   0.83985 |
# | rmse_difference                         0.0617 |
# | train_rmse                             0.90155 |
# +------------------------------------------------+
#
# Trial objective_64145_00008 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00008 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 40 |
# | n_factors                                50 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00009 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00009 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   10 |
# | n_factors                                 100 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial status: 8 TERMINATED | 2 RUNNING | 71 PENDING
# Current time: 2024-11-03 21:49:23. Total running time: 37s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# Current best trial: 64145_00005 with rmse=0.8381768107819348 and params={'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.01}
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status         n_factors     n_epochs     lr_all     reg_all     iter     total time (s)     train_rmse       rmse     rmse_difference |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | objective_64145_00008   RUNNING               50           40     0.01          0.01                                                                           |
# | objective_64145_00009   RUNNING              100           10     0.0025        0.01                                                                           |
# | objective_64145_00000   TERMINATED            50           10     0.0025        0.01        1           0.246034       0.900504   0.855925           0.0445786 |
# | objective_64145_00001   TERMINATED            50           10     0.005         0.01        1           0.243836       0.900503   0.847731           0.0527717 |
# | objective_64145_00002   TERMINATED            50           10     0.01          0.01        1           0.362882       0.900739   0.843107           0.057632  |
# | objective_64145_00003   TERMINATED            50           20     0.0025        0.01        1           0.561424       0.900496   0.845838           0.0546575 |
# | objective_64145_00004   TERMINATED            50           20     0.005         0.01        1           0.309481       0.900726   0.843286           0.0574397 |
# | objective_64145_00010   PENDING              100           10     0.005         0.01                                                                           |
# | objective_64145_00011   PENDING              100           10     0.01          0.01                                                                           |
# | objective_64145_00012   PENDING              100           20     0.0025        0.01                                                                           |
# | objective_64145_00013   PENDING              100           20     0.005         0.01                                                                           |
# | objective_64145_00014   PENDING              100           20     0.01          0.01                                                                           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 3 more TERMINATED, 66 more PENDING
#
# Trial objective_64145_00009 completed after 1 iterations at 2024-11-03 21:49:23. Total running time: 37s
# +------------------------------------------------+
# | Trial objective_64145_00009 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.30959 |
# | time_total_s                           0.30959 |
# | training_iteration                           1 |
# | rmse                                   0.85801 |
# | rmse_difference                        0.04247 |
# | train_rmse                             0.90048 |
# +------------------------------------------------+
# (objective pid=2362) RMSE: 0.8580 [repeated 4x across cluster]
#
# Trial objective_64145_00008 completed after 1 iterations at 2024-11-03 21:49:23. Total running time: 37s
# +------------------------------------------------+
# | Trial objective_64145_00008 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.43602 |
# | time_total_s                           0.43602 |
# | training_iteration                           1 |
# | rmse                                   0.84826 |
# | rmse_difference                        0.05461 |
# | train_rmse                             0.90287 |
# +------------------------------------------------+
#
# Trial objective_64145_00010 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00010 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  10 |
# | n_factors                                100 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00011 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00011 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 10 |
# | n_factors                               100 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00010 completed after 1 iterations at 2024-11-03 21:49:29. Total running time: 43s
# +------------------------------------------------+
# | Trial objective_64145_00010 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.31293 |
# | time_total_s                           0.31293 |
# | training_iteration                           1 |
# | rmse                                   0.84953 |
# | rmse_difference                        0.05097 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
# (objective pid=2523) RMSE: 0.8495 [repeated 4x across cluster]
#
# Trial objective_64145_00011 completed after 1 iterations at 2024-11-03 21:49:29. Total running time: 43s
# +------------------------------------------------+
# | Trial objective_64145_00011 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.30825 |
# | time_total_s                           0.30825 |
# | training_iteration                           1 |
# | rmse                                   0.84388 |
# | rmse_difference                        0.05684 |
# | train_rmse                             0.90071 |
# +------------------------------------------------+
#
# Trial objective_64145_00013 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00013 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  20 |
# | n_factors                                100 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00012 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00012 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   20 |
# | n_factors                                 100 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00013 completed after 1 iterations at 2024-11-03 21:49:36. Total running time: 50s
# +------------------------------------------------+
# | Trial objective_64145_00013 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.79216 |
# | time_total_s                           0.79216 |
# | training_iteration                           1 |
# | rmse                                   0.84228 |
# | rmse_difference                        0.05847 |
# | train_rmse                             0.90075 |
# +------------------------------------------------+
# (objective pid=2675) RMSE: 0.8423 [repeated 4x across cluster]
#
# Trial objective_64145_00012 completed after 1 iterations at 2024-11-03 21:49:36. Total running time: 50s
# +------------------------------------------------+
# | Trial objective_64145_00012 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.65433 |
# | time_total_s                           0.65433 |
# | training_iteration                           1 |
# | rmse                                   0.84736 |
# | rmse_difference                        0.05315 |
# | train_rmse                             0.90051 |
# +------------------------------------------------+
#
# Trial objective_64145_00015 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00015 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   40 |
# | n_factors                                 100 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00014 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00014 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 20 |
# | n_factors                               100 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00014 completed after 1 iterations at 2024-11-03 21:49:42. Total running time: 56s
# +------------------------------------------------+
# | Trial objective_64145_00014 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.42834 |
# | time_total_s                           0.42834 |
# | training_iteration                           1 |
# | rmse                                   0.84827 |
# | rmse_difference                        0.05315 |
# | train_rmse                             0.90142 |
# +------------------------------------------------+
# (objective pid=2840) RMSE: 0.8483 [repeated 4x across cluster]
#
# Trial objective_64145_00015 completed after 1 iterations at 2024-11-03 21:49:42. Total running time: 56s
# +------------------------------------------------+
# | Trial objective_64145_00015 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.60368 |
# | time_total_s                           0.60368 |
# | training_iteration                           1 |
# | rmse                                   0.84557 |
# | rmse_difference                        0.05514 |
# | train_rmse                             0.90071 |
# +------------------------------------------------+
#
# Trial objective_64145_00017 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00017 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 40 |
# | n_factors                               100 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00016 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00016 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  40 |
# | n_factors                                100 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
# (objective pid=2997) RMSE: 0.9013 [repeated 3x across cluster]
#
# Trial objective_64145_00017 completed after 1 iterations at 2024-11-03 21:49:50. Total running time: 1min 4s
# +------------------------------------------------+
# | Trial objective_64145_00017 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       1.16341 |
# | time_total_s                           1.16341 |
# | training_iteration                           1 |
# | rmse                                   0.84795 |
# | rmse_difference                        0.05435 |
# | train_rmse                              0.9023 |
# +------------------------------------------------+
#
# Trial objective_64145_00016 completed after 1 iterations at 2024-11-03 21:49:50. Total running time: 1min 4s
# +------------------------------------------------+
# | Trial objective_64145_00016 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       1.12976 |
# | time_total_s                           1.12976 |
# | training_iteration                           1 |
# | rmse                                    0.8443 |
# | rmse_difference                        0.05698 |
# | train_rmse                             0.90128 |
# +------------------------------------------------+
#
# Trial status: 18 TERMINATED | 63 PENDING
# Current time: 2024-11-03 21:49:53. Total running time: 1min 7s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# Current best trial: 64145_00005 with rmse=0.8381768107819348 and params={'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.01}
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status         n_factors     n_epochs     lr_all     reg_all     iter     total time (s)     train_rmse       rmse     rmse_difference |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | objective_64145_00000   TERMINATED            50           10     0.0025        0.01        1           0.246034       0.900504   0.855925           0.0445786 |
# | objective_64145_00001   TERMINATED            50           10     0.005         0.01        1           0.243836       0.900503   0.847731           0.0527717 |
# | objective_64145_00002   TERMINATED            50           10     0.01          0.01        1           0.362882       0.900739   0.843107           0.057632  |
# | objective_64145_00003   TERMINATED            50           20     0.0025        0.01        1           0.561424       0.900496   0.845838           0.0546575 |
# | objective_64145_00004   TERMINATED            50           20     0.005         0.01        1           0.309481       0.900726   0.843286           0.0574397 |
# | objective_64145_00018   PENDING              200           10     0.0025        0.01                                                                           |
# | objective_64145_00019   PENDING              200           10     0.005         0.01                                                                           |
# | objective_64145_00020   PENDING              200           10     0.01          0.01                                                                           |
# | objective_64145_00021   PENDING              200           20     0.0025        0.01                                                                           |
# | objective_64145_00022   PENDING              200           20     0.005         0.01                                                                           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 13 more TERMINATED, 58 more PENDING
#
# Trial objective_64145_00018 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00018 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   10 |
# | n_factors                                 200 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00019 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00019 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  10 |
# | n_factors                                200 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00018 completed after 1 iterations at 2024-11-03 21:49:57. Total running time: 1min 11s
# +------------------------------------------------+
# | Trial objective_64145_00018 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.43177 |
# | time_total_s                           0.43177 |
# | training_iteration                           1 |
# | rmse                                   0.86349 |
# | rmse_difference                        0.03701 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
# (objective pid=3162) RMSE: 0.8635 [repeated 5x across cluster]
#
# Trial objective_64145_00019 completed after 1 iterations at 2024-11-03 21:49:57. Total running time: 1min 11s
# +------------------------------------------------+
# | Trial objective_64145_00019 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.40531 |
# | time_total_s                           0.40531 |
# | training_iteration                           1 |
# | rmse                                   0.85406 |
# | rmse_difference                         0.0464 |
# | train_rmse                             0.90046 |
# +------------------------------------------------+
#
# Trial objective_64145_00020 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00020 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 10 |
# | n_factors                               200 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00021 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00021 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   20 |
# | n_factors                                 200 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
# (objective pid=3318) RMSE: 0.8515 [repeated 4x across cluster]
# Trial objective_64145_00020 completed after 1 iterations at 2024-11-03 21:50:02. Total running time: 1min 16s
# +------------------------------------------------+
# | Trial objective_64145_00020 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.43975 |
# | time_total_s                           0.43975 |
# | training_iteration                           1 |
# | rmse                                    0.8515 |
# | rmse_difference                        0.04923 |
# | train_rmse                             0.90073 |
# +------------------------------------------------+
#
#
# Trial objective_64145_00021 completed after 1 iterations at 2024-11-03 21:50:02. Total running time: 1min 16s
# +------------------------------------------------+
# | Trial objective_64145_00021 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.56219 |
# | time_total_s                           0.56219 |
# | training_iteration                           1 |
# | rmse                                   0.85704 |
# | rmse_difference                        0.04348 |
# | train_rmse                             0.90052 |
# +------------------------------------------------+
#
# Trial objective_64145_00022 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00022 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  20 |
# | n_factors                                200 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00023 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00023 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 20 |
# | n_factors                               200 |
# | reg_all                                0.01 |
# +---------------------------------------------+
# (objective pid=3478) RMSE: 0.9007 [repeated 3x across cluster]
#
# Trial objective_64145_00022 completed after 1 iterations at 2024-11-03 21:50:11. Total running time: 1min 25s
# +------------------------------------------------+
# | Trial objective_64145_00022 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.64237 |
# | time_total_s                           0.64237 |
# | training_iteration                           1 |
# | rmse                                   0.85118 |
# | rmse_difference                        0.04951 |
# | train_rmse                             0.90069 |
# +------------------------------------------------+
#
# Trial objective_64145_00023 completed after 1 iterations at 2024-11-03 21:50:11. Total running time: 1min 25s
# +------------------------------------------------+
# | Trial objective_64145_00023 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                        0.6183 |
# | time_total_s                            0.6183 |
# | training_iteration                           1 |
# | rmse                                    0.8495 |
# | rmse_difference                        0.05165 |
# | train_rmse                             0.90115 |
# +------------------------------------------------+
#
# Trial objective_64145_00025 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00025 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  40 |
# | n_factors                                200 |
# | reg_all                                 0.01 |
# +----------------------------------------------+
#
# Trial objective_64145_00024 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00024 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   40 |
# | n_factors                                 200 |
# | reg_all                                  0.01 |
# +-----------------------------------------------+
#
# Trial objective_64145_00025 completed after 1 iterations at 2024-11-03 21:50:17. Total running time: 1min 31s
# +------------------------------------------------+
# | Trial objective_64145_00025 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       1.00595 |
# | time_total_s                           1.00595 |
# | training_iteration                           1 |
# | rmse                                   0.85099 |
# | rmse_difference                        0.05002 |
# | train_rmse                               0.901 |
# +------------------------------------------------+
#
# Trial objective_64145_00024 completed after 1 iterations at 2024-11-03 21:50:17. Total running time: 1min 31s
# +------------------------------------------------+
# | Trial objective_64145_00024 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                        0.9578 |
# | time_total_s                            0.9578 |
# | training_iteration                           1 |
# | rmse                                   0.84988 |
# | rmse_difference                        0.05074 |
# | train_rmse                             0.90062 |
# +------------------------------------------------+
# (objective pid=3640) RMSE: 0.8499 [repeated 5x across cluster]
#
# Trial status: 26 TERMINATED | 55 PENDING
# Current time: 2024-11-03 21:50:23. Total running time: 1min 37s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# Current best trial: 64145_00005 with rmse=0.8381768107819348 and params={'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.01}
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status         n_factors     n_epochs     lr_all     reg_all     iter     total time (s)     train_rmse       rmse     rmse_difference |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | objective_64145_00000   TERMINATED            50           10     0.0025        0.01        1           0.246034       0.900504   0.855925           0.0445786 |
# | objective_64145_00001   TERMINATED            50           10     0.005         0.01        1           0.243836       0.900503   0.847731           0.0527717 |
# | objective_64145_00002   TERMINATED            50           10     0.01          0.01        1           0.362882       0.900739   0.843107           0.057632  |
# | objective_64145_00003   TERMINATED            50           20     0.0025        0.01        1           0.561424       0.900496   0.845838           0.0546575 |
# | objective_64145_00004   TERMINATED            50           20     0.005         0.01        1           0.309481       0.900726   0.843286           0.0574397 |
# | objective_64145_00026   PENDING              200           40     0.01          0.01                                                                           |
# | objective_64145_00027   PENDING               50           10     0.0025        0.02                                                                           |
# | objective_64145_00028   PENDING               50           10     0.005         0.02                                                                           |
# | objective_64145_00029   PENDING               50           10     0.01          0.02                                                                           |
# | objective_64145_00030   PENDING               50           20     0.0025        0.02                                                                           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 21 more TERMINATED, 50 more PENDING
#
# Trial objective_64145_00026 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00026 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 40 |
# | n_factors                               200 |
# | reg_all                                0.01 |
# +---------------------------------------------+
#
# Trial objective_64145_00027 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00027 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   10 |
# | n_factors                                  50 |
# | reg_all                                  0.02 |
# +-----------------------------------------------+
# (objective pid=3797) RMSE: 0.8560 [repeated 4x across cluster]
#
# Trial objective_64145_00027 completed after 1 iterations at 2024-11-03 21:50:25. Total running time: 1min 39s
# +------------------------------------------------+
# | Trial objective_64145_00027 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.44669 |
# | time_total_s                           0.44669 |
# | training_iteration                           1 |
# | rmse                                   0.85599 |
# | rmse_difference                         0.0445 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
#
# Trial objective_64145_00026 completed after 1 iterations at 2024-11-03 21:50:25. Total running time: 1min 39s
# +------------------------------------------------+
# | Trial objective_64145_00026 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       1.25794 |
# | time_total_s                           1.25794 |
# | training_iteration                           1 |
# | rmse                                   0.84974 |
# | rmse_difference                        0.05168 |
# | train_rmse                             0.90142 |
# +------------------------------------------------+
#
# Trial objective_64145_00028 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00028 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  10 |
# | n_factors                                 50 |
# | reg_all                                 0.02 |
# +----------------------------------------------+
#
# Trial objective_64145_00029 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00029 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 10 |
# | n_factors                                50 |
# | reg_all                                0.02 |
# +---------------------------------------------+
#
# Trial objective_64145_00028 completed after 1 iterations at 2024-11-03 21:50:31. Total running time: 1min 45s
# +------------------------------------------------+
# | Trial objective_64145_00028 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.24431 |
# | time_total_s                           0.24431 |
# | training_iteration                           1 |
# | rmse                                   0.84703 |
# | rmse_difference                        0.05347 |
# | train_rmse                              0.9005 |
# +------------------------------------------------+
# (objective pid=3967) RMSE: 0.9007 [repeated 3x across cluster]
#
# Trial objective_64145_00029 completed after 1 iterations at 2024-11-03 21:50:31. Total running time: 1min 45s
# +------------------------------------------------+
# | Trial objective_64145_00029 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.25041 |
# | time_total_s                           0.25041 |
# | training_iteration                           1 |
# | rmse                                   0.84313 |
# | rmse_difference                        0.05761 |
# | train_rmse                             0.90074 |
# +------------------------------------------------+
#
# Trial objective_64145_00031 started with configuration:
# +----------------------------------------------+
# | Trial objective_64145_00031 config           |
# +----------------------------------------------+
# | lr_all                                 0.005 |
# | n_epochs                                  20 |
# | n_factors                                 50 |
# | reg_all                                 0.02 |
# +----------------------------------------------+
#
# Trial objective_64145_00030 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00030 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   20 |
# | n_factors                                  50 |
# | reg_all                                  0.02 |
# +-----------------------------------------------+
#
# Trial objective_64145_00031 completed after 1 iterations at 2024-11-03 21:50:38. Total running time: 1min 52s
# +------------------------------------------------+
# | Trial objective_64145_00031 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.51842 |
# | time_total_s                           0.51842 |
# | training_iteration                           1 |
# | rmse                                   0.84073 |
# | rmse_difference                           0.06 |
# | train_rmse                             0.90073 |
# +------------------------------------------------+
# (objective pid=4125) RMSE: 0.8407 [repeated 5x across cluster]
#
# Trial objective_64145_00030 completed after 1 iterations at 2024-11-03 21:50:38. Total running time: 1min 52s
# +------------------------------------------------+
# | Trial objective_64145_00030 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                       0.51347 |
# | time_total_s                           0.51347 |
# | training_iteration                           1 |
# | rmse                                    0.8491 |
# | rmse_difference                        0.05138 |
# | train_rmse                             0.90048 |
# +------------------------------------------------+
#
# Trial objective_64145_00032 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00032 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 20 |
# | n_factors                                50 |
# | reg_all                                0.02 |
# +---------------------------------------------+
#
# Trial objective_64145_00033 started with configuration:
# +-----------------------------------------------+
# | Trial objective_64145_00033 config            |
# +-----------------------------------------------+
# | lr_all                                 0.0025 |
# | n_epochs                                   40 |
# | n_factors                                  50 |
# | reg_all                                  0.02 |
# +-----------------------------------------------+
#
# ...
# | checkpoint_dir_name                            |
# | time_this_iter_s                       1.07886 |
# | time_total_s                           1.07886 |
# | training_iteration                           1 |
# | rmse                                   0.84947 |
# | rmse_difference                        0.05173 |
# | train_rmse                              0.9012 |
# +------------------------------------------------+(objective pid=7969) RMSE: 0.8452 [repeated 4x across cluster]
#
#
# Trial objective_64145_00080 started with configuration:
# +---------------------------------------------+
# | Trial objective_64145_00080 config          |
# +---------------------------------------------+
# | lr_all                                 0.01 |
# | n_epochs                                 40 |
# | n_factors                               200 |
# | reg_all                                0.04 |
# +---------------------------------------------+
# 2024-11-03 21:53:33,300	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/content/results/demo_experiment' in 0.0493s.
# Trial objective_64145_00080 completed after 1 iterations at 2024-11-03 21:53:33. Total running time: 4min 47s
# +------------------------------------------------+
# | Trial objective_64145_00080 result             |
# +------------------------------------------------+
# | checkpoint_dir_name                            |
# | time_this_iter_s                        0.6359 |
# | time_total_s                            0.6359 |
# | training_iteration                           1 |
# | rmse                                   0.84795 |
# | rmse_difference                        0.05381 |
# | train_rmse                             0.90176 |
# +------------------------------------------------+
#
# Trial status: 81 TERMINATED
# Current time: 2024-11-03 21:53:33. Total running time: 4min 47s
# Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
# Current best trial: 64145_00005 with rmse=0.8381768107819348 and params={'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.01}
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status         n_factors     n_epochs     lr_all     reg_all     iter     total time (s)     train_rmse       rmse     rmse_difference |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | objective_64145_00000   TERMINATED            50           10     0.0025        0.01        1           0.246034       0.900504   0.855925           0.0445786 |
# | objective_64145_00001   TERMINATED            50           10     0.005         0.01        1           0.243836       0.900503   0.847731           0.0527717 |
# | objective_64145_00002   TERMINATED            50           10     0.01          0.01        1           0.362882       0.900739   0.843107           0.057632  |
# | objective_64145_00003   TERMINATED            50           20     0.0025        0.01        1           0.561424       0.900496   0.845838           0.0546575 |
# | objective_64145_00004   TERMINATED            50           20     0.005         0.01        1           0.309481       0.900726   0.843286           0.0574397 |
# | objective_64145_00005   TERMINATED            50           20     0.01          0.01        1           0.295892       0.901586   0.838177           0.0634094 |
# | objective_64145_00006   TERMINATED            50           40     0.0025        0.01        1           0.507586       0.900752   0.840759           0.0599935 |
# | objective_64145_00007   TERMINATED            50           40     0.005         0.01        1           0.509402       0.901553   0.83985            0.0617035 |
# | objective_64145_00008   TERMINATED            50           40     0.01          0.01        1           0.436016       0.902869   0.84826            0.0546088 |
# | objective_64145_00009   TERMINATED           100           10     0.0025        0.01        1           0.309588       0.900481   0.858009           0.0424719 |
# | objective_64145_00010   TERMINATED           100           10     0.005         0.01        1           0.312926       0.900502   0.849528           0.0509737 |
# | objective_64145_00011   TERMINATED           100           10     0.01          0.01        1           0.308255       0.900713   0.843875           0.0568379 |
# | objective_64145_00012   TERMINATED           100           20     0.0025        0.01        1           0.654333       0.900509   0.847357           0.053152  |
# | objective_64145_00013   TERMINATED           100           20     0.005         0.01        1           0.792162       0.900753   0.842281           0.0584716 |
# | objective_64145_00014   TERMINATED           100           20     0.01          0.01        1           0.428338       0.901425   0.848271           0.0531542 |
# | objective_64145_00015   TERMINATED           100           40     0.0025        0.01        1           0.603683       0.90071    0.845571           0.0551385 |
# | objective_64145_00016   TERMINATED           100           40     0.005         0.01        1           1.12976        0.901276   0.8443             0.0569758 |
# | objective_64145_00017   TERMINATED           100           40     0.01          0.01        1           1.16341        0.902296   0.84795            0.0543459 |
# | objective_64145_00018   TERMINATED           200           10     0.0025        0.01        1           0.431772       0.900498   0.863487           0.0370109 |
# | objective_64145_00019   TERMINATED           200           10     0.005         0.01        1           0.405314       0.900461   0.854065           0.0463965 |
# | objective_64145_00020   TERMINATED           200           10     0.01          0.01        1           0.439748       0.900729   0.851499           0.0492303 |
# | objective_64145_00021   TERMINATED           200           20     0.0025        0.01        1           0.562192       0.900523   0.857044           0.0434791 |
# | objective_64145_00022   TERMINATED           200           20     0.005         0.01        1           0.642368       0.900694   0.851183           0.0495114 |
# | objective_64145_00023   TERMINATED           200           20     0.01          0.01        1           0.618296       0.901147   0.849499           0.0516477 |
# | objective_64145_00024   TERMINATED           200           40     0.0025        0.01        1           0.957802       0.90062    0.849884           0.0507359 |
# | objective_64145_00025   TERMINATED           200           40     0.005         0.01        1           1.00595        0.901002   0.850986           0.0500158 |
# | objective_64145_00026   TERMINATED           200           40     0.01          0.01        1           1.25794        0.901418   0.849739           0.0516788 |
# | objective_64145_00027   TERMINATED            50           10     0.0025        0.02        1           0.446687       0.900498   0.855994           0.0445031 |
# | objective_64145_00028   TERMINATED            50           10     0.005         0.02        1           0.244307       0.900502   0.847033           0.0534688 |
# | objective_64145_00029   TERMINATED            50           10     0.01          0.02        1           0.250413       0.900738   0.84313            0.0576078 |
# | objective_64145_00030   TERMINATED            50           20     0.0025        0.02        1           0.513473       0.900479   0.849102           0.051377  |
# | objective_64145_00031   TERMINATED            50           20     0.005         0.02        1           0.518421       0.900725   0.840728           0.0599974 |
# | objective_64145_00032   TERMINATED            50           20     0.01          0.02        1           0.325598       0.901544   0.841796           0.0597482 |
# | objective_64145_00033   TERMINATED            50           40     0.0025        0.02        1           0.382441       0.900735   0.84092            0.0598149 |
# | objective_64145_00034   TERMINATED            50           40     0.005         0.02        1           0.554909       0.901596   0.84396            0.0576364 |
# | objective_64145_00035   TERMINATED            50           40     0.01          0.02        1           0.55105        0.903256   0.846673           0.0565832 |
# | objective_64145_00036   TERMINATED           100           10     0.0025        0.02        1           0.304892       0.900484   0.856659           0.043824  |
# | objective_64145_00037   TERMINATED           100           10     0.005         0.02        1           0.285297       0.900501   0.849123           0.0513775 |
# | objective_64145_00038   TERMINATED           100           10     0.01          0.02        1           0.302403       0.900708   0.846744           0.0539639 |
# | objective_64145_00039   TERMINATED           100           20     0.0025        0.02        1           0.393075       0.900504   0.850798           0.0497059 |
# | objective_64145_00040   TERMINATED           100           20     0.005         0.02        1           0.444255       0.900707   0.843765           0.0569423 |
# | objective_64145_00041   TERMINATED           100           20     0.01          0.02        1           0.418528       0.901325   0.845272           0.0560531 |
# | objective_64145_00042   TERMINATED           100           40     0.0025        0.02        1           0.666075       0.900725   0.842007           0.0587177 |
# | objective_64145_00043   TERMINATED           100           40     0.005         0.02        1           0.669147       0.901361   0.847081           0.0542801 |
# | objective_64145_00044   TERMINATED           100           40     0.01          0.02        1           1.1697         0.902164   0.847136           0.0550286 |
# | objective_64145_00045   TERMINATED           200           10     0.0025        0.02        1           0.819318       0.900484   0.859199           0.0412859 |
# | objective_64145_00046   TERMINATED           200           10     0.005         0.02        1           0.437239       0.900485   0.850268           0.0502174 |
# | objective_64145_00047   TERMINATED           200           10     0.01          0.02        1           0.423773       0.900657   0.847782           0.0528751 |
# | objective_64145_00048   TERMINATED           200           20     0.0025        0.02        1           0.634912       0.900489   0.856183           0.0443055 |
# | objective_64145_00049   TERMINATED           200           20     0.005         0.02        1           0.563738       0.900533   0.845002           0.0555309 |
# | objective_64145_00050   TERMINATED           200           20     0.01          0.02        1           0.610524       0.901118   0.847707           0.0534104 |
# | objective_64145_00051   TERMINATED           200           40     0.0025        0.02        1           0.833963       0.900661   0.848432           0.0522297 |
# | objective_64145_00052   TERMINATED           200           40     0.005         0.02        1           1.01393        0.901063   0.846867           0.0541958 |
# | objective_64145_00053   TERMINATED           200           40     0.01          0.02        1           1.015          0.901561   0.846245           0.0553155 |
# | objective_64145_00054   TERMINATED            50           10     0.0025        0.04        1           0.421349       0.900493   0.853848           0.0466451 |
# | objective_64145_00055   TERMINATED            50           10     0.005         0.04        1           0.42635        0.900502   0.847236           0.0532659 |
# | objective_64145_00056   TERMINATED            50           10     0.01          0.04        1           0.252305       0.900735   0.840858           0.0598773 |
# | objective_64145_00057   TERMINATED            50           20     0.0025        0.04        1           0.193698       0.900508   0.847819           0.0526888 |
# | objective_64145_00058   TERMINATED            50           20     0.005         0.04        1           0.472376       0.900721   0.840838           0.0598822 |
# | objective_64145_00059   TERMINATED            50           20     0.01          0.04        1           0.559895       0.901571   0.842059           0.0595128 |
# | objective_64145_00060   TERMINATED            50           40     0.0025        0.04        1           0.49596        0.900748   0.843057           0.0576907 |
# | objective_64145_00061   TERMINATED            50           40     0.005         0.04        1           0.253595       0.901597   0.841635           0.0599614 |
# | objective_64145_00062   TERMINATED            50           40     0.01          0.04        1           0.480057       0.903301   0.847569           0.0557316 |
# | objective_64145_00063   TERMINATED           100           10     0.0025        0.04        1           0.294819       0.900494   0.859729           0.0407654 |
# | objective_64145_00064   TERMINATED           100           10     0.005         0.04        1           0.33234        0.900483   0.849854           0.0506293 |
# | objective_64145_00065   TERMINATED           100           10     0.01          0.04        1           0.309643       0.900712   0.841754           0.0589574 |
# | objective_64145_00066   TERMINATED           100           20     0.0025        0.04        1           0.459055       0.900496   0.84835            0.0521456 |
# | objective_64145_00067   TERMINATED           100           20     0.005         0.04        1           0.404349       0.900682   0.844573           0.0561089 |
# | objective_64145_00068   TERMINATED           100           20     0.01          0.04        1           0.790441       0.901347   0.844886           0.0564606 |
# | objective_64145_00069   TERMINATED           100           40     0.0025        0.04        1           1.08317        0.900763   0.844338           0.0564251 |
# | objective_64145_00070   TERMINATED           100           40     0.005         0.04        1           0.59009        0.901381   0.840655           0.0607256 |
# | objective_64145_00071   TERMINATED           100           40     0.01          0.04        1           0.664198       0.90247    0.84634            0.0561297 |
# | objective_64145_00072   TERMINATED           200           10     0.0025        0.04        1           0.483768       0.900483   0.860014           0.0404694 |
# | objective_64145_00073   TERMINATED           200           10     0.005         0.04        1           0.50504        0.900486   0.853954           0.0465314 |
# | objective_64145_00074   TERMINATED           200           10     0.01          0.04        1           0.412923       0.900583   0.850365           0.0502176 |
# | objective_64145_00075   TERMINATED           200           20     0.0025        0.04        1           0.523161       0.900513   0.849857           0.0506566 |
# | objective_64145_00076   TERMINATED           200           20     0.005         0.04        1           1.28438        0.900692   0.849283           0.0514092 |
# | objective_64145_00077   TERMINATED           200           20     0.01          0.04        1           1.11705        0.901172   0.848695           0.0524763 |
# | objective_64145_00078   TERMINATED           200           40     0.0025        0.04        1           1.02381        0.900642   0.845192           0.0554502 |
# | objective_64145_00079   TERMINATED           200           40     0.005         0.04        1           1.07886        0.901199   0.849471           0.0517285 |
# | objective_64145_00080   TERMINATED           200           40     0.01          0.04        1           0.635898       0.901763   0.847952           0.0538118 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Lowest RMSE Model: {'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.01, 'reg_all': 0.01}

# %%
# Set path to params.json and result.json file corresponding to experiment
params_path = '/content/results/demo_experiment/objective_64145_00000_0_lr_all=0.0025,n_epochs=10,n_factors=50,reg_all=0.0100_2024-11-03_21-48-49/params.json'
result_path = '/content/results/demo_experiment/objective_64145_00000_0_lr_all=0.0025,n_epochs=10,n_factors=50,reg_all=0.0100_2024-11-03_21-48-49/result.json'

# Load JSON files to analyze experiments
with open(params_path, 'r') as file:
    params_data = json.load(file)
print(json.dumps(params_data, indent = 4))

with open(result_path, 'r') as file:
    result_data = json.load(file)
print(json.dumps(result_data, indent = 4))
# Out:
# {
#     "lr_all": 0.0025,
#     "n_epochs": 10,
#     "n_factors": 50,
#     "reg_all": 0.01
# }
# {
#     "train_rmse": 0.900504084675624,
#     "rmse": 0.8559254541394724,
#     "rmse_difference": 0.04457863053615163,
#     "timestamp": 1730670536,
#     "checkpoint_dir_name": null,
#     "done": false,
#     "training_iteration": 1,
#     "trial_id": "64145_00000",
#     "date": "2024-11-03_21-48-56",
#     "time_this_iter_s": 0.2460336685180664,
#     "time_total_s": 0.2460336685180664,
#     "pid": 1718,
#     "hostname": "9e4a9774ff74",
#     "node_ip": "172.28.0.12",
#     "config": {
#         "n_factors": 50,
#         "n_epochs": 10,
#         "lr_all": 0.0025,
#         "reg_all": 0.01
#     },
#     "time_since_restore": 0.2460336685180664,
#     "iterations_since_restore": 1
# }
